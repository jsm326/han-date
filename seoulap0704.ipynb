# %% [markdown]
# ## 서울시 재개발 재건축 정비사업 현황

# %%
import pandas as pd
import requests

# %%
url = "http://openAPI.seoul.go.kr:8088/4a496d74426a736d34327a6b6a4c55/json/CleanupBussinessInfo/1/5/금천구"

# %%
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
data = r.json()

data
# Out:
# {'CleanupBussinessInfo': {'list_total_count': 25,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'BIZ_NO': '11545-900001113',
#     'CGG_NM': '금천구',
#     'STDG_NM': '시흥동',
#     'BIZ_SE': '가로주택정비',
#     'OPER_SE': '조합',
#     'ASCT_NM': '시흥5동1구역 919번지일원 가로주택정비사업',
#     'RPRS_LOTNO': '시흥동 919',
#     'PRGRS_SEQ': '조합설립인가',
#     'STTS': '운영',
#     'OWNR_CNT': 123.0,
#     'MTNC_AREA_NM': '시흥5동1구역 919번지일원 가로주택정비사업',
#     'MTNC_AREA_PSTN': '금천구 시흥동 919-0',
#     'MTNC_AREA': 10397.0,
#     'MTNC_TOT_AREA': 36270.47,
#     'USG_AREA': '소규모주택관리지역',
#     'USG_DSTRCT': '2종일반주거지역→(3종일반주거지역 종상향 예정)',
#     'AREA_RGN': 10397.0,
#     'AREA_ROAD': 0.0,
#     'AREA_PARK': 0.0,
#     'AREA_GRN': 0.0,
#     'AREA_GG': 0.0,
#     'AREA_SCHL': 0.0,
#     'AREA_ETC': 0.0,
#     'MAIN_USG': '공공주택(아파트)및부대복리시설',
#     'BDCVRT': 0.0,
#     'FART': 238.36,
#     'HGT': 0.0,
#     'GRND_NOFL': 15.0,
#     'UDGD_NOFL': 2.0,
#     'LTOT_HSHLD_NO': 0.0,
#     'AREA_60': 64.0,
# ...

# %%
cleanup = data['CleanupBussinessInfo']['row']
cleanup
# Out:
# [{'BIZ_NO': '11545-900001113',
#   'CGG_NM': '금천구',
#   'STDG_NM': '시흥동',
#   'BIZ_SE': '가로주택정비',
#   'OPER_SE': '조합',
#   'ASCT_NM': '시흥5동1구역 919번지일원 가로주택정비사업',
#   'RPRS_LOTNO': '시흥동 919',
#   'PRGRS_SEQ': '조합설립인가',
#   'STTS': '운영',
#   'OWNR_CNT': 123.0,
#   'MTNC_AREA_NM': '시흥5동1구역 919번지일원 가로주택정비사업',
#   'MTNC_AREA_PSTN': '금천구 시흥동 919-0',
#   'MTNC_AREA': 10397.0,
#   'MTNC_TOT_AREA': 36270.47,
#   'USG_AREA': '소규모주택관리지역',
#   'USG_DSTRCT': '2종일반주거지역→(3종일반주거지역 종상향 예정)',
#   'AREA_RGN': 10397.0,
#   'AREA_ROAD': 0.0,
#   'AREA_PARK': 0.0,
#   'AREA_GRN': 0.0,
#   'AREA_GG': 0.0,
#   'AREA_SCHL': 0.0,
#   'AREA_ETC': 0.0,
#   'MAIN_USG': '공공주택(아파트)및부대복리시설',
#   'BDCVRT': 0.0,
#   'FART': 238.36,
#   'HGT': 0.0,
#   'GRND_NOFL': 15.0,
#   'UDGD_NOFL': 2.0,
#   'LTOT_HSHLD_NO': 0.0,
#   'AREA_60': 64.0,
#   'AREA_60_85': 173.0,
#   'AREA_85': 0.0,
#   'RENT_HH_TOT_CNT': 0.0,
#   'RENT_40': 0.0,
#   'RENT_40_50': 0.0,
#   'RENT_50': 0.0,
#   'ARCH_PLAN': '',
# ...
